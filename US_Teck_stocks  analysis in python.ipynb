# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
from pandas_datareader import data, wb, DataReader
from datetime import datetime
from __future__ import division

# %%
tech_list=['AAPL','GOOG','MSFT','AMZN','MMM']

# %%
end=datetime.now()

# %%
start=datetime(end.year-1,end.month,end.day)

# %%
for stock in tech_list:
    globals()[stock]=DataReader(stock,'yahoo',start,end)

# %%
AAPL.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  253.000000  253.000000  253.000000  253.000000  2.530000e+02
# mean   106.743597  107.644466  106.061976  106.923953  3.544596e+07
# std      8.738483    8.760474    8.831691    8.837839  1.514592e+07
# min     90.000000   91.669998   89.470001   90.339996  1.142440e+07
# 25%     98.529999   99.300003   97.550003   98.660004  2.631520e+07
# 50%    107.709999  108.440002  106.820000  107.790001  3.157790e+07
# 75%    113.459999  114.309998  112.510002  113.540001  3.891900e+07
# max    130.539993  132.089996  130.449997  131.529999  1.146021e+08
#
#         Adj Close
# count  253.000000
# mean   106.119465
# std      9.235161
# min     89.394274
# 25%     97.627183
# 50%    107.149865
# 75%    112.969990
# max    131.529999

# %%
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 253 entries, 2016-02-08 to 2017-02-07
# Data columns (total 6 columns):
# Open         253 non-null float64
# High         253 non-null float64
# Low          253 non-null float64
# Close        253 non-null float64
# Volume       253 non-null int64
# Adj Close    253 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 13.8 KB

# %%
ax=AAPL['Adj Close'].plot(legend=True,figsize=(10,4))
ax.set_xlabel("Date")
ax.set_ylabel("Apple Price")

# %%
ax=GOOG['Adj Close'].plot(legend=True, figsize=(10,4))
ax.set_xlabel("Date")
ax.set_ylabel("Google Price")

# %%
ax=MSFT['Adj Close'].plot(legend=True, figsize=(10,4))
ax.set_xlabel("Date")
ax.set_ylabel("Microsoft Price")

# %%
AAPL['Volume'].plot(legend=True,figsize=(10,4))

# %%
ax=AMZN['Adj Close'].plot(legend=True, figsize=(10,4))

ax.set_xlabel("Date")
ax.set_ylabel("Amazon Price")

# %%
ma_day=[10,20,50]

for ma in ma_day:
    column_name="MA for %s days" %(str(ma))
    
    AAPL[column_name]=pd.rolling_mean(AAPL['Adj Close'],ma)
# Out:
# F:\anaconda\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=10,center=False).mean()
# F:\anaconda\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=20,center=False).mean()
# F:\anaconda\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,center=False).mean()

# %%
GOOG
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2016-02-08  667.849976  684.030029  663.059998  682.739990  4247400
# 2016-02-09  672.320007  699.900024  668.770020  678.109985  3608900
# 2016-02-10  686.859985  701.309998  682.130005  684.119995  2638000
# 2016-02-11  675.000000  689.349976  668.867981  683.109985  3024000
# 2016-02-12  690.260010  693.750000  678.599976  682.400024  2141400
# 2016-02-16  692.979980  698.000000  685.049988  691.000000  2520000
# 2016-02-17  698.090027  709.750000  691.380005  708.400024  2492600
# 2016-02-18  710.000000  712.349976  696.030029  697.349976  1883200
# 2016-02-19  695.030029  703.080994  694.049988  700.909973  1589300
# 2016-02-22  707.450012  713.239990  702.510010  706.460022  1949800
# 2016-02-23  701.450012  708.400024  693.580017  695.849976  2009300
# 2016-02-24  688.919983  700.000000  680.780029  699.559998  1963600
# 2016-02-25  700.010010  705.979980  690.585022  705.750000  1642200
# ...

# %%
AAPL[['Adj Close', 'MA for 10 days','MA for 20 days','MA for 50 days']].plot(subplots=False,figsize=(10,4))

# %%
ma_day=[10,20,50]

for ma in ma_day:
    column_name="MA for %s days" %(str(ma))
    
    GOOG[column_name]=pd.rolling_mean(GOOG['Adj Close'],ma)
# Out:
# F:\anaconda\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=10,center=False).mean()
# F:\anaconda\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=20,center=False).mean()
# F:\anaconda\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,center=False).mean()

# %%
AAPL['Daily Return']=AAPL['Adj Close'].pct_change()

AAPL['Daily Return'].plot(figsize=(10,4),legend=True,linestyle='--')

# %%
GOOG[['Adj Close', 'MA for 10 days','MA for 20 days','MA for 50 days']].plot(subplots=False,figsize=(10,4))

# %%
GOOG['Daily Return']=AAPL['Adj Close'].pct_change()

GOOG['Daily Return'].plot(figsize=(10,4),legend=True,linestyle='--')

# %%
MSFT['Daily Return']=AAPL['Adj Close'].pct_change()

MSFT['Daily Return'].plot(figsize=(10,4),legend=True,linestyle='--')

# %%
AMZN['Daily Return']=AAPL['Adj Close'].pct_change()

AMZN['Daily Return'].plot(figsize=(10,4),legend=True,linestyle='--')

# %%
sns.distplot(AAPL['Daily Return'].dropna(), bins=100, color='purple')

# %%
sns.distplot(GOOG['Daily Return'].dropna(), bins=100, color='red')

# %%
sns.distplot(MSFT['Daily Return'].dropna(), bins=100, color='blue')

# %%
sns.distplot(AMZN['Daily Return'].dropna(), bins=100, color='green')

# %%
AAPL['Daily Return'].hist(bins=100)

# %%
closing_df=DataReader(tech_list,'yahoo', start,end)['Adj Close']
closing_df.head()
# Out:
#                  AAPL        AMZN        GOOG       MSFT
# Date
# 2016-02-08  93.446449  488.100006  682.739990  48.090390
# 2016-02-09  93.426774  482.070007  678.109985  47.963861
# 2016-02-10  92.718621  490.480011  684.119995  48.382377
# 2016-02-11  92.158002  503.820007  683.109985  48.362910
# 2016-02-12  92.443230  507.079987  682.400024  49.151279

# %%
tech_rets=closing_df.pct_change()

# %%
tech_rets.head()
# Out:
#                 AAPL      AMZN      GOOG      MSFT
# Date
# 2016-02-08       NaN       NaN       NaN       NaN
# 2016-02-09 -0.000211 -0.012354 -0.006782 -0.002631
# 2016-02-10 -0.007580  0.017446  0.008863  0.008726
# 2016-02-11 -0.006046  0.027198 -0.001476 -0.000402
# 2016-02-12  0.003095  0.006471 -0.001039  0.016301

# %%
sns.jointplot('GOOG','GOOG',tech_rets,kind='scatter',color='seagreen')

# %%
sns.jointplot('GOOG','AAPL',tech_rets,kind='scatter',color='seagreen')

# %%
sns.jointplot('GOOG','MSFT',tech_rets,kind='scatter',color='seagreen')

# %%
tech_rets.head()
# Out:
#                 AAPL      AMZN      GOOG      MSFT
# Date
# 2016-02-08       NaN       NaN       NaN       NaN
# 2016-02-09 -0.000211 -0.012354 -0.006782 -0.002631
# 2016-02-10 -0.007580  0.017446  0.008863  0.008726
# 2016-02-11 -0.006046  0.027198 -0.001476 -0.000402
# 2016-02-12  0.003095  0.006471 -0.001039  0.016301

# %%
sns.pairplot(tech_rets.dropna())

# %%
returns_fig=sns.PairGrid(tech_rets.dropna())

returns_fig.map_upper(plt.scatter, color='purple')

returns_fig.map_lower(sns.kdeplot,cmap='cool_d')

returns_fig.map_diag(plt.hist, bins=30)

# %%
returns_fig=sns.PairGrid(closing_df)

returns_fig.map_upper(plt.scatter, color='purple')

returns_fig.map_lower(sns.kdeplot,cmap='cool_d')

returns_fig.map_diag(plt.hist, bins=30)

# %%
corrmat = tech_rets.dropna().corr() 
sns.heatmap(corrmat, vmax=1, square=True)

# %%
rets=tech_rets.dropna()

# %%
area=np.pi*15

plt.scatter(rets.mean(),rets.std(),s=area)

plt.xlabel('Expected returns')

plt.ylabel('Risk')

for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (50, 50),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        arrowprops = dict(arrowstyle = '-', connectionstyle = 'arc3,rad=-0.3'))

# %%
sns.distplot(AAPL['Daily Return'].dropna(),bins=100, color='purple')

# %%
rets.head()
# Out:
#                 AAPL      AMZN      GOOG      MSFT
# Date
# 2016-02-09 -0.000211 -0.012354 -0.006782 -0.002631
# 2016-02-10 -0.007580  0.017446  0.008863  0.008726
# 2016-02-11 -0.006046  0.027198 -0.001476 -0.000402
# 2016-02-12  0.003095  0.006471 -0.001039  0.016301
# 2016-02-16  0.028195  0.027648  0.012603  0.018947

# %%
rets['AAPL'].quantile(0.05)
# Out:
# -0.020747924597211573

# %%
days=365
dt=1/days
mu=rets.mean()['GOOG']
sigma=rets.std()["GOOG"]

# %%
def stock_monte_carlo(start_price, days, mu,sigma):
    price=np.zeros(days)
    price[0]=start_price
    
    shock=np.zeros(days)
    drift=np.zeros(days)
    
    for x in xrange(1,days):
        shock[x]=np.random.normal(loc=mu*dt, scale=sigma*np.sqrt(dt))
        drift[x]=mu*dt
        price[x]=price[x-1]+(price[x-1]*(drift[x]+shock[x]))
        
    return price

# %%
GOOG.head()
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2016-02-08  667.849976  684.030029  663.059998  682.739990  4247400
# 2016-02-09  672.320007  699.900024  668.770020  678.109985  3608900
# 2016-02-10  686.859985  701.309998  682.130005  684.119995  2638000
# 2016-02-11  675.000000  689.349976  668.867981  683.109985  3024000
# 2016-02-12  690.260010  693.750000  678.599976  682.400024  2141400
#
#              Adj Close
# Date
# 2016-02-08  682.739990
# 2016-02-09  678.109985
# 2016-02-10  684.119995
# 2016-02-11  683.109985
# 2016-02-12  682.400024

# %%
start_price=746.13

for run in xrange(100):
    plt.plot(stock_monte_carlo(start_price, days, mu,sigma))
    
plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Monte Carlo Analysis for Google')

# %%
runs=10000

simulations=np.zeros(runs)

for run in xrange(runs):
    simulations[run]=stock_monte_carlo(start_price,days, mu, sigma)[days-1]

# %%
q=np.percentile(simulations,1)

plt.hist(simulations,bins=200)

# Starting Price
plt.figtext(0.6, 0.8, s="Start price: $%.2f" %start_price)
# Mean ending price
plt.figtext(0.6, 0.7, "Mean final price: $%.2f" % simulations.mean())

# Variance of the price (within 99% confidence interval)
plt.figtext(0.6, 0.6, "VaR(0.99): $%.2f" % (start_price - q,))

# Display 1% quantile
plt.figtext(0.15, 0.6, "q(0.99): $%.2f" % q)

# Plot a line at the 1% quantile result
plt.axvline(x=q, linewidth=4, color='r')

# Title
plt.title(u"Final price distribution for Google Stock after %s days" % days, weight='bold');
